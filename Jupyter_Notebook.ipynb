# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo">
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # The Final Project

# %% [markdown]
# ## introduction
# This project includes 12 exercises in Data Science, convering commonly used languages,libraries,tools and arithmetic expression examples.

# %% [markdown]
# ## commonly used data science languages
# - python
# - R
# - SQL
# - C++

# %% [markdown]
# ## data science libraries
# ### python libraries
# - Numpy
# - Pandas
# - Matplotlib
# ### R libraries
# - ggplot2
# - dplyr
# - tidyverse
# - plotly

# %% [markdown]
# ## data science tools
# | Tool Category | Tools'Name |
# |---------------|------------|
# | data management tools | MySQL,postgreSQL,Apache Cassandra,Elasticsearch,Ceph,CouchDB,MongoDB,Hadoop HDFS |
# | operating system tools | Jupyter IDE,Pycharm,Rstudio,Spyder,Microsoft Visual Studio,Anaconda Navigator |
# | Data integration and transformation tools | Spark SQL,Kubeflow,Node-RED,Airflow,nifi,kaffa |
# |data visualization tools | PixieDust,Kibana,Hue,Superset |
# | model tools for building,deployment,monitoring and assessment | Apache Spark MLlib,TensorFlow,ModelDB,IBM Adversarial Robustness 360 Toolbox |
# | tools for code and data asset management | Git,GitHub,gitlab bitbucket,Apache Atlas,ODPi Egeria,Kylo |

# %% [markdown]
# ## introduce the arithmetic expression examples
# The result of '2+3' is '5'.
# The result of '3*5' is '15'.
# The result of '2+2*3' is '8'.

# %%
print(f"Multiply:3*7={3*7}")
print(f"Add     :3+7={3+7}")
# Out:
# Multiply:3*7=21
# Add     :3+7=10

# %%
# convert minutes to hours
minutes = 210
hours = minutes/60
print(f"{minutes} minutes = {hours} hours")
# Out:
# 210 minutes = 3.5 hours

# %% [markdown]
# ## Objectives
# - Exercise 2 - Create a markdown cell with the title of the notebook. (1 pt)
# - Exercise 3 - Create a markdown cell for an introduction. (1 pt)
# - Exercise 4 - Create a markdown cell to list data science languages. (3 pts)
# - Exercise 5 - Create a markdown cell to list data science libraries. (3 pts)
# - Exercise 6 - Create a markdown cell with a table of Data Science tools. (3 pts)
# - Exercise 7 - Create a markdown cell introducing arithmetic expression examples. (1 pt)
# - Exercise 8 - Create a code cell to multiply and add numbers. (2 pts)
# - Exercise 9 - Create a code cell to convert minutes to hours. (2 pts)
# - Exercise 10 -Insert a markdown cell to list Objectives. (3 pts)
# - Exercise 11 - Create a markdown cell to indicate the Author’s name. (2 pts)
# - Exercise 12 - Share your notebook through GitHub (3 pts)
# - Exercise 13 - Take a screenshot of the first page of the notebook. (1 pt)

# %% [markdown]
# ### Author's name:彭庆琳
